# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize']=5,4

# %%
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]

b
ax.plot(x,y)

# %%
fig=plt.figure() #figure object 
ax=fig.add_axes([.1,.1,1,1]) #add_axes(Left,bottom,width,height)

ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.set_xticks([0,1,2,5,6,8,9])
ax.set_yticks([0,1,2,4,5])

ax.plot(x,y)

# %%
fig=plt.figure() #figure object 
ax=fig.add_axes([.1,.1,1,1]) #add_axes(Left,bottom,width,height)

ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.grid()
ax.plot(x,y)

# %%
fig=plt.figure()
fig, (ax1,ax2) = plt.subplots(1,2) #subplots(rows,columns)

ax1.plot(x)
ax2.plot(y)
