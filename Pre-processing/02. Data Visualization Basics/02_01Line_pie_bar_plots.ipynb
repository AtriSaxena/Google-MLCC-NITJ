# %%
! pip install Seaborn
# Out:
# Requirement already satisfied: Seaborn in c:\users\bond\anaconda3\lib\site-packages

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')

# %%
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
plt.plot(x,y) #Line Plot

# %%
address="C:\Data_jupyter\mtcars.csv"
cars=pd.read_csv(address)
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
mpg=cars['mpg']

# %%
mpg.plot() #bar charts using panda object

# %%
df=cars[['cyl','wt','mpg']]
df.plot()

# %%
#Bar charts
plt.bar(x,y)
# Out:
# <Container object of 9 artists>

# %%
#bar charts using pandas
mpg.plot(kind='bar')

# %%
mpg.plot(kind='barh')

# %%
rcParams['figure.figsize']=15,5
df.plot(kind='bar')

# %%
#Pie Chart
rcParams['figure.figsize']=5,5
x=[1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %%
plt.savefig('pie_chart.jpeg')
plt.show()

# %%
# %pwd
# Out:
# 'C:\\Users\\BoNd'
