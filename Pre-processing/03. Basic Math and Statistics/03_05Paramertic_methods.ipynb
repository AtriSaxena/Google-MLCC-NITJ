# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from pylab import rcParams 

import scipy
from scipy.stats.stats import pearsonr

# %%
# %matplotlib inline
rcParams['figure.figsize']=8,4
plt.style.use('seaborn-whitegrid')

# %%
#Pearson Corelation
address="C:\Data_jupyter\mtcars.csv"
cars=pd.read_csv(address)
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
sb.pairplot(cars)

# %% [markdown]
# The pairs plot builds on two basic figures, the histogram and the scatter plot. The histogram on the diagonal allows us to see the distribution of a single variable while the scatter plots on the upper and lower triangles show the relationship (or lack thereof) between two variables.

# %%
x=cars[['mpg','hp','qsec','wt']]
sb.pairplot(x)

# %%
mpg=cars['mpg']
hp=cars['hp']
qsec=cars['qsec']
wt=cars['wt']
pearsonr_coefficient,p_value=pearsonr(mpg,hp)
print("PeasronR correlation coefficient {}".format(pearsonr_coefficient))
# Out:
# PeasronR correlation coefficient -0.7761683718265864

# %%
pearsonr_coefficient,p_value=pearsonr(mpg,qsec)
print("PeasronR correlation coefficient {}".format(pearsonr_coefficient))
# Out:
# PeasronR correlation coefficient 0.4186840339217782

# %%
pearsonr_coefficient,p_value=pearsonr(mpg,wt)
print("PeasronR correlation coefficient {}".format(pearsonr_coefficient))
# Out:
# PeasronR correlation coefficient -0.8676593765172279

# %%
# pearson corelation using pandas
corr=x.corr() #return corelation of each
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %%
#visualize the corelation using seaborn

sb.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values)
